# %%
def Check_Domicile(age,d_region):
    d_region.lower()
    if age >= 18:
        if d_region=="Lahore":
            print("Eligble for position")
    else:
        print("not eligible")
Check_Domicile(20,"Lahore")
# Out:
# Eligble for position
